# %% [markdown]
# ## 3. Importing Libraries

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
## Assigning path
path = r'C:\Users\vinor\01-2020 Instacart Basket Analysis'

# %%
## Import Customer dataframe
df_custm = pd.read_csv(os.path.join(path,'02 Data','Original Data','customers.csv'),index_col = False)

# %% [markdown]
# ## 4.wrangle the data in customer dataset

# %%
df_custm.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
## Customer dataset has totally 10 columns. from my point all the columns are necessary for analysis,so i didnt drop any coulmn.
## some column name to be renamed as surname, dependants, family_status.

# %%
## Renaming the column surnam to Surmane
df_custm.rename(columns = {'Surnam' : 'Surname'}, inplace = True)

# %%
df_custm.head()
# Out:
#    user_id First Name   Surname  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
## Renaming the column n_dependants to Dependants
df_custm.rename(columns = {'n_dependants' : 'Dependants'},  inplace = True)

# %%
df_custm.head()
# Out:
#    user_id First Name   Surname  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    Dependants fam_status  income
# 0           3    married  165665
# 1           0     single   59285
# 2           2    married   99568
# 3           0     single   42049
# 4           1    married   40374

# %%
## Renaming the column fam_status to Family_status
df_custm.rename(columns = {'fam_status' : 'Family_status'},  inplace = True)

# %%
df_custm.head()
# Out:
#    user_id First Name   Surname  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    Dependants Family_status  income
# 0           3       married  165665
# 1           0        single   59285
# 2           2       married   99568
# 3           0        single   42049
# 4           1       married   40374

# %% [markdown]
# ## 5.Data quality and Consistency checks in customer dataframe

# %%
df_custm.describe()
# Out:
#              user_id            Age     Dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %%
df_custm.shape
# Out:
# (206209, 10)

# %%
## convert any mixed-type data.
## Checking the datatype for all columns in the customer dataset.
df_custm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        206209 non-null  int64
#  1   First Name     194950 non-null  object
#  2   Surname        206209 non-null  object
#  3   Gender         206209 non-null  object
#  4   STATE          206209 non-null  object
#  5   Age            206209 non-null  int64
#  6   date_joined    206209 non-null  object
#  7   Dependants     206209 non-null  int64
#  8   Family_status  206209 non-null  object
#  9   income         206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %%
## date_joined datatype is assigned as object, it should be datetime datatype.

# %%
## Changing the datatype from object to datetime for date_joined column.
df_custm['date_joined'] = pd.to_datetime(df_custm['date_joined'])

# %%
df_custm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        206209 non-null  int64
#  1   First Name     194950 non-null  object
#  2   Surname        206209 non-null  object
#  3   Gender         206209 non-null  object
#  4   STATE          206209 non-null  object
#  5   Age            206209 non-null  int64
#  6   date_joined    206209 non-null  datetime64[ns]
#  7   Dependants     206209 non-null  int64
#  8   Family_status  206209 non-null  object
#  9   income         206209 non-null  int64
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 15.7+ MB

# %%
## Finding Missing Values
df_custm.isnull().sum()
# Out:
# user_id              0
# First Name       11259
# Surname              0
# Gender               0
# STATE                0
# Age                  0
# date_joined          0
# Dependants           0
# Family_status        0
# income               0
# dtype: int64

# %%
## Addressing missing values
## 11259 first_name is missing in customer dataset. We can not remove those values. So it should be as it is.
## Those missing first_name customers surname are there.

# %%
## Duplicates
# command to look for full duplicates within the dataframe
df_dups = df_custm[df_custm.duplicated()]

# %%
## No duplicates are found. 
df_dups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   user_id        0 non-null      int64
#  1   First Name     0 non-null      object
#  2   Surname        0 non-null      object
#  3   Gender         0 non-null      object
#  4   STATE          0 non-null      object
#  5   Age            0 non-null      int64
#  6   date_joined    0 non-null      datetime64[ns]
#  7   Dependants     0 non-null      int64
#  8   Family_status  0 non-null      object
#  9   income         0 non-null      int64
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 0.0+ bytes

# %% [markdown]
# ## 6. Combine the customer data with the rest of your prepared Instacart data.

# %%
## Import ords_prods_merge data
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', '4.8_orders_products_merged.pkl'))

# %%
df_ords_prods_merge.shape
# Out:
# (32434212, 25)

# %%
# Merge the df_ords_prods_merge with customer data frame
df_ords_prods_custm = df_ords_prods_merge.merge(df_custm, on = ['user_id'], indicator = True)

# %%
df_ords_prods_custm['_merge'].value_counts()
# Out:
# _merge
# both          32434212
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_ords_prods_custm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434212 entries, 0 to 32434211
# Data columns (total 35 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   order_id                       int64
#  1   user_id                        int64
#  2   eval_set                       object
#  3   order_number                   int64
#  4   order_dow                      int64
#  5   order_hour_of_day              int64
#  6   days_since_prior_order         float64
#  7   product_id                     int64
#  8   add_to_cart_order              int64
#  9   reordered                      int64
#  10  Unnamed: 0                     int64
#  11  product_name                   object
#  12  aisle_id                       int64
#  13  department_id                  int64
#  14  prices                         float64
#  15  price_range_loc                object
#  16  busiest_day                    object
# ...

# %%
df_ords_prods_custm.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                     NaN         196                  1          0  ...
# 1                    15.0         196                  1          1  ...
# 2                    21.0         196                  1          1  ...
# 3                    29.0         196                  1          1  ...
# 4                    28.0         196                  1          1  ...
#
#    First Name Surname  Gender    STATE  Age date_joined Dependants  \
# ...

# %% [markdown]
# ## 8. Export the new dataframe as a pickle file

# %%
df_ords_prods_custm.to_pickle(os.path.join(path, '02 Data','Prepared Data', '4.9_ords_prods_custm.pkl'))
